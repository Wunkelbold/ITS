# %%
1000*12
# Out:
# 12000

# %%
2*(8912-2348+23)-400
# Out:
# 12774

# %%
123**456
# Out:
# ...

# %%
(12**3 +13**4)**0.5 / 2**0.5
# Out:
# 123.06299200003224

# %%
2**(2**17)
# Out:
# ...

# %%
len(str(2**(2**17)))
# Out:
# 39457

# %%
str(2**10000)[41]
# Out:
# '9'

# %%
str(2**10000).count("4")
# Out:
# 292

# %%
str(2**10000)[999]=="1" or str(2**10000)[999]=="3"
# Out:
# False

# %%
if(str(2**10000)[999]=="1" or str(2**10000)[999]=="3" and str(2**10000)[1999]=="1" or str(2**10000)[1999]=="3" ): 
        print("yes")
else: 
        print("no")
# Out:
# no

# %%
import math
(complex(2,5))**(complex(-1,2))
# Out:
# (-0.009786278952990838+0.014115672821230931j)

# %%
(complex(0,1))**(complex(0,1))
# Out:
# (0.20787957635076193+0j)

# %%
if((345745**0.5)==int(345745**0.5)):print("yes")

# %%
(345744**0.5)==int(345744**0.5)
# Out:
# True

# %%
def diegrossenzwei(a,b,c):
    stri=(a,b,c)
    stri=sorted(stri)
    return stri[len(stri)-1]+stri[len(stri)-2]
    
diegrossenzwei(3,3,5)
# Out:
# 8

# %%
liste=[]

def diegrossenzwei(liste):
    sorted(liste)
    return liste[len(liste)-1]+liste[len(liste)-2]
    
diegrossenzwei([1,3,3])
# Out:
# 6
