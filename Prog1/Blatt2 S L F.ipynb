# %%
#Aufgabe 2.0
def eingabe():
    x=input("Hier einbgeben:")
    if(x[0]=="A"):
        return x.replace("A","a",1)
    return x
eingabe()
# Out:
# Hier einbgeben:AlterA
# 'alterA'

# %%
#Aufgabe 2.1 a)

from random import randint

def ratespiel(n):
    loesung=randint(0,n)
    x=int(input("Hier eingeben:"))
    while(x!=loesung):   
        if(x>loesung):print("kleiner")
        if(x<loesung):print("größer")
        x=int(input("Hier eingeben:"))
    return "winner winner chicken dinner"
    return 

ratespiel(50)
# Out:
# Hier eingeben:23
# kleiner
# Hier eingeben:34
# kleiner
# Hier eingeben:34
# kleiner
# Hier eingeben:34
# kleiner
# Hier eingeben:45
# kleiner
# Hier eingeben:56
# kleiner
# Hier eingeben:67
# kleiner
# Hier eingeben:87
# kleiner
# Hier eingeben:89
# kleiner
# Hier eingeben:n
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [140], in <cell line: 15>()
#      12     return "winner winner chicken dinner"
#      13     return
# ---> 15 ratespiel(50)
#
# Input In [140], in ratespiel(n)
#       9     if(x>loesung):print("kleiner")
#      10     if(x<loesung):print("größer")
# ---> 11     x=int(input("Hier eingeben:"))
#      12 return "winner winner chicken dinner"
#      13 return
#
# ValueError: invalid literal for int() with base 10: 'n'

# %%
#Aufgabe 2.1

def rate(n):
    rN=randint(0,1000)
    while(rN!=n):
        if(randint(0,1000)<n):print("größer")
        if(randint(0,1000)>n):print("kleiner")
        rN=randint(0,1000)
    return print("winner winner chicken dinner")

rate(50)
# Out:
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# größer
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# größer
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# größer
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# größer
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# kleiner
# ...

# %%
def rate(gewinn):
    untere=0
    obere=1000
    i=0
    rateNummer=((obere-untere)/2)+untere
    while(rateNummer!=gewinn):
        i=i+1
        if(rateNummer<gewinn):
            untere=rateNummer
        if(rateNummer>gewinn):
            obere=rateNummer
        rateNummer=((obere-untere)/2)+untere
        
        
    return print("winner winner chicken dinner it took", i ,"rounds")
        
rate(843)
# Out:
# winner winner chicken dinner it took 47 rounds
