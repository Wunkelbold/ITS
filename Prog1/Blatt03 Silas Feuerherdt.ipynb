# %%
 #Aufgabe 3.0

stud=[2,3,4]
prof=[1,2,3]

def beliebig(*l):
    
    return l

beliebig(stud)
# Out:
# ([2, 3, 4],)

# %%
#Aufgabe 3.1 a
i=1
zahl=0
while(i<100000):
    zahl = zahl +(1/i**3)
    i +=1
   

print(zahl)
# Out:
# 1.2020569031097312

# %%
#Aufgabe 3.1 b
i=1
zahl=0
while(i<1000000):
    zahl = zahl +(1/i**2)
    i +=1

   

print((6*zahl)**0.5) #Umstellung der Gleichung "zahl= pi^2 /6" um pi auszugeben
# Out:
# 3.141591698659554

# %%
#Aufgabe 3.3



d = {
    "Name" : "BMW",
    "Farbe":"Blau",
    "Spurweite":2000,
    "Felgen":26,
    "Hubraum":3000,
    "Bauform":"V8",
    "Abgasnorm":"D3",
    }

# a) 
print(len(d))   

# b)     
if(d.get('Hallo')):print(d.get('Hallo')) 
else:print("No key 'Hallo'")    

# c) korrigiert
intCount=0
for x in d:             
    if(type(d[x])==int):
        intCount+=1

if(intCount==len(d)):print("Alle sind int")
else:print("Nur",intCount,"von",len(d),"sind integer")

# d) korrigiert
d[1]="2"
# Out:
# 7
# No key 'Hallo'
# Nur 3 von 7 sind integer

# %%
#Aufgabe 3.2 NEU

alphabet=['a','e','i','o','u','q','w','r','t','z','p','s','d','f','g','h','j','k','l','y','x','c','v','b','n','m']
konsonanten=['q','w','r','t','z','p','s','d','f','g','h','j','k','l','y','x','c','v','b','n','m']
eCounter=0
zCounter=0
dCounter=0
vCounter=0

def check_for_kons(e,z,d,v):
    konsonantFounde=False
    konsonantFoundz=False
    konsonantFoundd=False
    konsonantFoundv=False
    eCheckCounter=0
    zCheckCounter=0
    dCheckCounter=0
    vCheckCounter=0
    
    while(eCheckCounter<=20):
        if(e==konsonanten[eCheckCounter]):
            konsonantFounde=True
        eCheckCounter+=1
    
    while(zCheckCounter<=20):
        if(z==konsonanten[zCheckCounter]):
            konsonantFoundz=True
        zCheckCounter+=1

    while(dCheckCounter<=20):
        if(d==konsonanten[dCheckCounter]):
            konsonantFoundd=True
        dCheckCounter+=1
    
    while(vCheckCounter<=20):
        if(v==konsonanten[vCheckCounter]):
            konsonantFoundv=True
        vCheckCounter+=1

    if((konsonantFounde and konsonantFoundz and konsonantFoundd)or(konsonantFoundz and konsonantFoundd and konsonantFoundv)):
        1+1
    else:print(e,z,d,v)
     




print("****************PROGRAMM START********************") 
print("**************************************************")
for eCounter in range(26):
    e=str(alphabet[eCounter])
    eCounter+=1
    for zCounter in range(26):
        z=str(alphabet[zCounter])
        zCounter +=1
        for dCounter in range(26):
            d=str(alphabet[dCounter])
            dCounter +=1 
            for vCounter in range(26):
                v=str(alphabet[vCounter])
                check_for_kons(e,z,d,v)
                vCounter +=1
# Out:
# ****************PROGRAMM START********************
# **************************************************
# a a a a
# a a a e
# a a a i
# a a a o
# a a a u
# a a a q
# a a a w
# a a a r
# a a a t
# a a a z
# a a a p
# a a a s
# a a a d
# a a a f
# a a a g
# a a a h
# a a a j
# a a a k
# a a a l
# a a a y
# a a a x
# a a a c
# a a a v
# a a a b
# a a a n
# a a a m
# a a e a
# a a e e
# a a e i
# a a e o
# a a e u
# a a e q
# a a e w
# a a e r
# a a e t
# a a e z
# a a e p
# a a e s
# a a e d
# a a e f
# a a e g
# a a e h
# a a e j
# a a e k
# a a e l
# a a e y
# a a e x
# a a e c
# a a e v
# a a e b
# a a e n
# a a e m
# a a i a
# a a i e
# a a i i
# a a i o
# a a i u
# a a i q
# a a i w
# a a i r
# a a i t
# a a i z
# a a i p
# a a i s
# a a i d
# a a i f
# a a i g
# a a i h
# a a i j
# a a i k
# a a i l
# a a i y
# a a i x
# a a i c
# a a i v
# a a i b
# a a i n
# a a i m
# a a o a
# a a o e
# a a o i
# a a o o
# a a o u
# a a o q
# a a o w
# a a o r
# a a o t
# a a o z
# a a o p
# ...
